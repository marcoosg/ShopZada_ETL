# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the Data

# %%
df_campaign_data = pd.read_csv('../marketing_department/campaign_data.csv')
df_transaction_campaign_data = pd.read_csv('../marketing_department/transactional_campaign_data.csv')

# %% [markdown]
# ### Data Profiling : df_campaign_data

# %%
df_campaign_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 1 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   	campaign_id	campaign_name	campaign_description	discount  10 non-null     object
# dtypes: object(1)
# memory usage: 212.0+ bytes

# %%
df_campaign_data.head(10)
# Out:
#   \tcampaign_id\tcampaign_name\tcampaign_description\tdiscount
# 0  0\tCAMPAIGN24776\twouldn't you know it\t"""Twe...
# 1  1\tCAMPAIGN33679\tcould be written on the back...
# 2  2\tCAMPAIGN49972\tme neither\t"""DIY pug leggi...
# 3  3\tCAMPAIGN61872\ton the huh\t"""Trust fund pi...
# 4  4\tCAMPAIGN03110\tstick a fork in it\t"""YOLO ...
# 5  5\tCAMPAIGN46302\tyou must be new here\t"""Cra...
# 6  6\tCAMPAIGN11190\tmind your own beeswax\t"""St...
# 7  7\tCAMPAIGN53595\thow do I get to the train st...
# 8  8\tCAMPAIGN29983\twould it hurt\t"""Vegan miga...
# 9  9\tCAMPAIGN52447\tpound for pound\t"""Semiotic...

# %%
#separating one cell to multiple cells
df_campaign_data[['Unnamed', 'campaign_id' , 'campaign_name', 'campaign_description', 'discount']] = df_campaign_data['\tcampaign_id\tcampaign_name\tcampaign_description\tdiscount'].str.split('\t', expand=True)

# %% [markdown]
# ### Removing unnecessary columns

# %%
df_campaign_data.drop('Unnamed', inplace=True, axis=1)

# %%
df_campaign_data.drop('\tcampaign_id\tcampaign_name\tcampaign_description\tdiscount', inplace=True, axis=1)

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             wouldn't you know it
# 1  CAMPAIGN33679  could be written on the back of a postage stamp
# 2  CAMPAIGN49972                                       me neither
# 3  CAMPAIGN61872                                       on the huh
# 4  CAMPAIGN03110                               stick a fork in it
# 5  CAMPAIGN46302                             you must be new here
# 6  CAMPAIGN11190                            mind your own beeswax
# 7  CAMPAIGN53595                how do I get to the train station
# 8  CAMPAIGN29983                                    would it hurt
# 9  CAMPAIGN52447                                  pound for pound
#
#                                 campaign_description  discount
# 0  """Twee retro vinyl single-origin coffee sarto...        1%
# 1  """Fanny pack gentrify cardigan messenger bag....      1pct
# 2  """DIY pug leggings everyday craft beer cardig...      10%%
# 3  """Trust fund pinterest chambray."" - Claude A...        5%
# 4     """YOLO tumblr Yuccie austin."" - Jordi Kunde"  1percent
# 5  """Craft beer XOXO hella tacos chillwave cred ...      1pct
# 6  """Street shoreditch viral before they sold ou...     10pct
# 7  """Craft beer venmo lomo fixie readymade marfa...     20pct
# 8  """Vegan migas ramps keytar wolf cray kickstar...        1%
# 9  """Semiotics biodiesel everyday craft beer ets...  1percent

# %%
print(df_campaign_data.shape)
# Out:
# (10, 4)

# %%
#cleaning campaign description by removing unnecessary symbols
df_campaign_data['campaign_description'] = df_campaign_data['campaign_description'].str.replace('"', '')

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             wouldn't you know it
# 1  CAMPAIGN33679  could be written on the back of a postage stamp
# 2  CAMPAIGN49972                                       me neither
# 3  CAMPAIGN61872                                       on the huh
# 4  CAMPAIGN03110                               stick a fork in it
# 5  CAMPAIGN46302                             you must be new here
# 6  CAMPAIGN11190                            mind your own beeswax
# 7  CAMPAIGN53595                how do I get to the train station
# 8  CAMPAIGN29983                                    would it hurt
# 9  CAMPAIGN52447                                  pound for pound
#
#                                 campaign_description  discount
# 0  Twee retro vinyl single-origin coffee sartoria...        1%
# 1  Fanny pack gentrify cardigan messenger bag. - ...      1pct
# 2  DIY pug leggings everyday craft beer cardigan ...      10%%
# 3  Trust fund pinterest chambray. - Claude Aufderhar        5%
# 4           YOLO tumblr Yuccie austin. - Jordi Kunde  1percent
# 5  Craft beer XOXO hella tacos chillwave cred org...      1pct
# 6  Street shoreditch viral before they sold out y...     10pct
# 7  Craft beer venmo lomo fixie readymade marfa. -...     20pct
# 8  Vegan migas ramps keytar wolf cray kickstarter...        1%
# 9  Semiotics biodiesel everyday craft beer etsy s...  1percent

# %%
#Cleaning structure in discount
df_campaign_data['discount'] = df_campaign_data['discount'].str.replace('%%', '%')

# %%
df_campaign_data['discount'] = df_campaign_data['discount'].str.replace('pct', '%')

# %%
df_campaign_data['discount'] = df_campaign_data['discount'].str.replace('percent', '%')

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             wouldn't you know it
# 1  CAMPAIGN33679  could be written on the back of a postage stamp
# 2  CAMPAIGN49972                                       me neither
# 3  CAMPAIGN61872                                       on the huh
# 4  CAMPAIGN03110                               stick a fork in it
# 5  CAMPAIGN46302                             you must be new here
# 6  CAMPAIGN11190                            mind your own beeswax
# 7  CAMPAIGN53595                how do I get to the train station
# 8  CAMPAIGN29983                                    would it hurt
# 9  CAMPAIGN52447                                  pound for pound
#
#                                 campaign_description discount
# 0  Twee retro vinyl single-origin coffee sartoria...       1%
# 1  Fanny pack gentrify cardigan messenger bag. - ...       1%
# 2  DIY pug leggings everyday craft beer cardigan ...      10%
# 3  Trust fund pinterest chambray. - Claude Aufderhar       5%
# 4           YOLO tumblr Yuccie austin. - Jordi Kunde       1%
# 5  Craft beer XOXO hella tacos chillwave cred org...       1%
# 6  Street shoreditch viral before they sold out y...      10%
# 7  Craft beer venmo lomo fixie readymade marfa. -...      20%
# 8  Vegan migas ramps keytar wolf cray kickstarter...       1%
# 9  Semiotics biodiesel everyday craft beer etsy s...       1%

# %%
#setting up width of column
pd.set_option('display.max_colwidth', None)

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             wouldn't you know it
# 1  CAMPAIGN33679  could be written on the back of a postage stamp
# 2  CAMPAIGN49972                                       me neither
# 3  CAMPAIGN61872                                       on the huh
# 4  CAMPAIGN03110                               stick a fork in it
# 5  CAMPAIGN46302                             you must be new here
# 6  CAMPAIGN11190                            mind your own beeswax
# 7  CAMPAIGN53595                how do I get to the train station
# 8  CAMPAIGN29983                                    would it hurt
# 9  CAMPAIGN52447                                  pound for pound
#
#                                                                                                     campaign_description  \
# 0                       Twee retro vinyl single-origin coffee sartorial fanny pack brunch offal health. - Raleigh Senger
# 1                                                            Fanny pack gentrify cardigan messenger bag. - Bradley Stamm
# 2                         DIY pug leggings everyday craft beer cardigan knausgaard +1 crucifix flannel. - Tremayne Nader
# 3                                                                      Trust fund pinterest chambray. - Claude Aufderhar
# 4                                                                               YOLO tumblr Yuccie austin. - Jordi Kunde
# 5                      Craft beer XOXO hella tacos chillwave cred organic letterpress disrupt artisan. - Rodrick Lebsack
# 6            Street shoreditch viral before they sold out yr ramps skateboard skateboard bitters pabst. - Brendan Miller
# 7                                                             Craft beer venmo lomo fixie readymade marfa. - Benny Bogan
# 8                                     Vegan migas ramps keytar wolf cray kickstarter five dollar toast. - Adeline Brakus
# 9  Semiotics biodiesel everyday craft beer etsy semiotics keffiyeh meditation single-origin coffee. - Bernadette Pollich
#
#   discount
# 0       1%
# 1       1%
# 2      10%
# 3       5%
# 4       1%
# 5       1%
# 6      10%
# 7      20%
# 8       1%
# 9       1%

# %%
df_campaign_data['campaign_name'] = df_campaign_data['campaign_name'].str.upper()

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             WOULDN'T YOU KNOW IT
# 1  CAMPAIGN33679  COULD BE WRITTEN ON THE BACK OF A POSTAGE STAMP
# 2  CAMPAIGN49972                                       ME NEITHER
# 3  CAMPAIGN61872                                       ON THE HUH
# 4  CAMPAIGN03110                               STICK A FORK IN IT
# 5  CAMPAIGN46302                             YOU MUST BE NEW HERE
# 6  CAMPAIGN11190                            MIND YOUR OWN BEESWAX
# 7  CAMPAIGN53595                HOW DO I GET TO THE TRAIN STATION
# 8  CAMPAIGN29983                                    WOULD IT HURT
# 9  CAMPAIGN52447                                  POUND FOR POUND
#
#                                                                                                     campaign_description  \
# 0                       Twee retro vinyl single-origin coffee sartorial fanny pack brunch offal health. - Raleigh Senger
# 1                                                            Fanny pack gentrify cardigan messenger bag. - Bradley Stamm
# 2                         DIY pug leggings everyday craft beer cardigan knausgaard +1 crucifix flannel. - Tremayne Nader
# 3                                                                      Trust fund pinterest chambray. - Claude Aufderhar
# 4                                                                               YOLO tumblr Yuccie austin. - Jordi Kunde
# 5                      Craft beer XOXO hella tacos chillwave cred organic letterpress disrupt artisan. - Rodrick Lebsack
# 6            Street shoreditch viral before they sold out yr ramps skateboard skateboard bitters pabst. - Brendan Miller
# 7                                                             Craft beer venmo lomo fixie readymade marfa. - Benny Bogan
# 8                                     Vegan migas ramps keytar wolf cray kickstarter five dollar toast. - Adeline Brakus
# 9  Semiotics biodiesel everyday craft beer etsy semiotics keffiyeh meditation single-origin coffee. - Bernadette Pollich
#
#   discount
# 0       1%
# 1       1%
# 2      10%
# 3       5%
# 4       1%
# 5       1%
# 6      10%
# 7      20%
# 8       1%
# 9       1%

# %%
df_campaign_data.duplicated().sum()
# Out:
# 0

# %%
#Separating Campaign description with writer
df_campaign_data[['campaign_description', 'campaign_writer']] = df_campaign_data['campaign_description'].str.split(" - ", expand=True)

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             WOULDN'T YOU KNOW IT
# 1  CAMPAIGN33679  COULD BE WRITTEN ON THE BACK OF A POSTAGE STAMP
# 2  CAMPAIGN49972                                       ME NEITHER
# 3  CAMPAIGN61872                                       ON THE HUH
# 4  CAMPAIGN03110                               STICK A FORK IN IT
# 5  CAMPAIGN46302                             YOU MUST BE NEW HERE
# 6  CAMPAIGN11190                            MIND YOUR OWN BEESWAX
# 7  CAMPAIGN53595                HOW DO I GET TO THE TRAIN STATION
# 8  CAMPAIGN29983                                    WOULD IT HURT
# 9  CAMPAIGN52447                                  POUND FOR POUND
#
#                                                                                campaign_description  \
# 0                   Twee retro vinyl single-origin coffee sartorial fanny pack brunch offal health.
# 1                                                       Fanny pack gentrify cardigan messenger bag.
# 2                     DIY pug leggings everyday craft beer cardigan knausgaard +1 crucifix flannel.
# 3                                                                    Trust fund pinterest chambray.
# 4                                                                        YOLO tumblr Yuccie austin.
# 5                   Craft beer XOXO hella tacos chillwave cred organic letterpress disrupt artisan.
# 6        Street shoreditch viral before they sold out yr ramps skateboard skateboard bitters pabst.
# 7                                                      Craft beer venmo lomo fixie readymade marfa.
# 8                                 Vegan migas ramps keytar wolf cray kickstarter five dollar toast.
# 9  Semiotics biodiesel everyday craft beer etsy semiotics keffiyeh meditation single-origin coffee.
#
#   discount     campaign_writer
# 0       1%      Raleigh Senger
# 1       1%       Bradley Stamm
# 2      10%      Tremayne Nader
# 3       5%    Claude Aufderhar
# 4       1%         Jordi Kunde
# 5       1%     Rodrick Lebsack
# 6      10%      Brendan Miller
# 7      20%         Benny Bogan
# 8       1%      Adeline Brakus
# 9       1%  Bernadette Pollich

# %%
df_campaign_data = df_campaign_data[['campaign_id', 'campaign_name', 'campaign_description', 'campaign_writer', 'campaign_discount']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df_campaign_data = df_campaign_data[['campaign_id', 'campaign_name', 'campaign_description', 'campaign_writer', 'campaign_discount']]
#
# File C:\Python34\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Python34\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File C:\Python34\Lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['campaign_discount'] not in index"

# %%
#renaming discount to campaign_discount
df_campaign_data = df_campaign_data.rename(columns={'discount': 'campaign_discount'})

# %%
df_campaign_data.head(10)
# Out:
#      campaign_id                                    campaign_name  \
# 0  CAMPAIGN24776                             WOULDN'T YOU KNOW IT
# 1  CAMPAIGN33679  COULD BE WRITTEN ON THE BACK OF A POSTAGE STAMP
# 2  CAMPAIGN49972                                       ME NEITHER
# 3  CAMPAIGN61872                                       ON THE HUH
# 4  CAMPAIGN03110                               STICK A FORK IN IT
# 5  CAMPAIGN46302                             YOU MUST BE NEW HERE
# 6  CAMPAIGN11190                            MIND YOUR OWN BEESWAX
# 7  CAMPAIGN53595                HOW DO I GET TO THE TRAIN STATION
# 8  CAMPAIGN29983                                    WOULD IT HURT
# 9  CAMPAIGN52447                                  POUND FOR POUND
#
#                                                                                campaign_description  \
# 0                   Twee retro vinyl single-origin coffee sartorial fanny pack brunch offal health.
# 1                                                       Fanny pack gentrify cardigan messenger bag.
# 2                     DIY pug leggings everyday craft beer cardigan knausgaard +1 crucifix flannel.
# 3                                                                    Trust fund pinterest chambray.
# 4                                                                        YOLO tumblr Yuccie austin.
# 5                   Craft beer XOXO hella tacos chillwave cred organic letterpress disrupt artisan.
# 6        Street shoreditch viral before they sold out yr ramps skateboard skateboard bitters pabst.
# 7                                                      Craft beer venmo lomo fixie readymade marfa.
# 8                                 Vegan migas ramps keytar wolf cray kickstarter five dollar toast.
# 9  Semiotics biodiesel everyday craft beer etsy semiotics keffiyeh meditation single-origin coffee.
#
#   campaign_discount     campaign_writer
# 0                1%      Raleigh Senger
# 1                1%       Bradley Stamm
# 2               10%      Tremayne Nader
# 3                5%    Claude Aufderhar
# 4                1%         Jordi Kunde
# 5                1%     Rodrick Lebsack
# 6               10%      Brendan Miller
# 7               20%         Benny Bogan
# 8                1%      Adeline Brakus
# 9                1%  Bernadette Pollich

# %% [markdown]
# ### Data Profiling and Cleaning - df_transaction_campaign_data

# %%
df_transaction_campaign_data.head(10)
# Out:
#    Unnamed: 0 transaction_date    campaign_id  \
# 0           2       2023-08-14  CAMPAIGN49972
# 1           4       2021-10-12  CAMPAIGN46302
# 2           6       2023-01-30  CAMPAIGN29983
# 3           8       2022-01-05  CAMPAIGN46302
# 4           9       2023-09-19  CAMPAIGN46302
# 5          16       2020-07-01  CAMPAIGN46302
# 6          22       2022-07-18  CAMPAIGN29983
# 7          24       2020-08-28  CAMPAIGN29983
# 8          27       2023-11-13  CAMPAIGN03110
# 9          33       2022-09-21  CAMPAIGN46302
#
#                                order_id estimated arrival  availed
# 0  0612c246-57f1-40e8-9993-0f8d41992049            10days        1
# 1  b4c411de-2fd3-4806-91ae-165edc9baa12            13days        0
# 2  26de6b40-db2d-40b9-a64c-58736eaf0381             3days        1
# 3  26b60a4e-aafe-4b99-bace-034d088a4a53             8days        1
# 4  4aab29ae-e610-46bf-92af-199f6f420cee            14days        1
# 5  3312851e-28dc-4508-8003-09ba304ce9e2            11days        1
# 6  9ae58335-164a-467c-ae22-fe5dabe806b9            10days        1
# 7  65abaa49-3ae1-44bb-8366-ef9d7e264a4c             7days        1
# 8  fd92cc32-e28e-4f14-b8f8-4526ea58fb3f             3days        1
# 9  61c61e9b-9838-4c95-8390-4343fbac7a18             9days        1

# %%
df_transaction_campaign_data.tail(10)
# Out:
#         Unnamed: 0 transaction_date    campaign_id  \
# 124877      499963       2020-02-04  CAMPAIGN24776
# 124878      499965       2021-11-23  CAMPAIGN29983
# 124879      499967       2022-01-06  CAMPAIGN33679
# 124880      499982       2022-02-14  CAMPAIGN46302
# 124881      499986       2022-01-23  CAMPAIGN11190
# 124882      499990       2022-04-14  CAMPAIGN61872
# 124883      499991       2022-11-23  CAMPAIGN11190
# 124884      499992       2023-07-28  CAMPAIGN33679
# 124885      499995       2020-04-12  CAMPAIGN49972
# 124886      499997       2023-03-24  CAMPAIGN52447
#
#                                     order_id estimated arrival  availed
# 124877  a397c17b-956f-4dce-8b0c-d8d6234f1de8            14days        1
# 124878  d5dbea32-829e-474c-8d88-cadcb993a944             8days        1
# 124879  238f761a-f1bf-4f6c-a37a-fff7f6574f8c            10days        1
# 124880  ceafa665-307f-4c9e-b1bd-79577a450eb9            12days        1
# 124881  f628455c-ad0a-444f-96c3-931f6a1912e9             9days        0
# 124882  6a5163c2-ba62-461c-a729-5b06fe266bd9            12days        0
# 124883  883e2fe2-bbdf-4b5e-8348-c2bcba07da0e            15days        1
# 124884  575b0a2d-5539-4565-a10b-1f4f6516cd27            12days        1
# 124885  ba506489-1505-481d-b0b1-8cdbf04a515f             6days        1
# 124886  2b2e775f-d6cd-4659-9a88-b4950bc326c0            15days        1

# %%
df_transaction_campaign_data['campaign_id'].nunique()
# Out:
# 10

# %%
#rename column
df_transaction_campaign_data = df_transaction_campaign_data.rename(columns={'estimated arrival': 'estimated_arrival'})

# %%
#Converting object to date
df_transaction_campaign_data['transaction_date'] = pd.to_datetime(df_transaction_campaign_data['transaction_date'])

# %%
df_transaction_campaign_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124887 entries, 0 to 124886
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         124887 non-null  int64
#  1   transaction_date   124887 non-null  datetime64[ns]
#  2   campaign_id        124887 non-null  object
#  3   order_id           124887 non-null  object
#  4   estimated_arrival  124887 non-null  object
#  5   availed            124887 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 5.7+ MB

# %%
# Adding space in between the number and days
df_transaction_campaign_data = df_transaction_campaign_data.assign(
    estimated_arrival = df_transaction_campaign_data['estimated_arrival'].str.extract(r'(\d+)') + " " + df_transaction_campaign_data['estimated_arrival'].str.extract(r'(\D+)')
    )

# %%
# Removal of unnamed column (NOT YET SUPER SURE - JUSTIFY THIS)
df_transaction_campaign_data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df_transaction_campaign_data.head()
# Out:
#   transaction_date    campaign_id                              order_id  \
# 0       2023-08-14  CAMPAIGN49972  0612c246-57f1-40e8-9993-0f8d41992049
# 1       2021-10-12  CAMPAIGN46302  b4c411de-2fd3-4806-91ae-165edc9baa12
# 2       2023-01-30  CAMPAIGN29983  26de6b40-db2d-40b9-a64c-58736eaf0381
# 3       2022-01-05  CAMPAIGN46302  26b60a4e-aafe-4b99-bace-034d088a4a53
# 4       2023-09-19  CAMPAIGN46302  4aab29ae-e610-46bf-92af-199f6f420cee
#
#   estimated_arrival  availed
# 0           10 days        1
# 1           13 days        0
# 2            3 days        1
# 3            8 days        1
# 4           14 days        1

# %%
#Change order of column
df_transaction_campaign_data = df_transaction_campaign_data[['order_id', 'campaign_id', 'transaction_date', 'estimated_arrival', 'availed']]

# %%
df_transaction_campaign_data.head(10)
# Out:
#                                order_id    campaign_id transaction_date  \
# 0  0612c246-57f1-40e8-9993-0f8d41992049  CAMPAIGN49972       2023-08-14
# 1  b4c411de-2fd3-4806-91ae-165edc9baa12  CAMPAIGN46302       2021-10-12
# 2  26de6b40-db2d-40b9-a64c-58736eaf0381  CAMPAIGN29983       2023-01-30
# 3  26b60a4e-aafe-4b99-bace-034d088a4a53  CAMPAIGN46302       2022-01-05
# 4  4aab29ae-e610-46bf-92af-199f6f420cee  CAMPAIGN46302       2023-09-19
# 5  3312851e-28dc-4508-8003-09ba304ce9e2  CAMPAIGN46302       2020-07-01
# 6  9ae58335-164a-467c-ae22-fe5dabe806b9  CAMPAIGN29983       2022-07-18
# 7  65abaa49-3ae1-44bb-8366-ef9d7e264a4c  CAMPAIGN29983       2020-08-28
# 8  fd92cc32-e28e-4f14-b8f8-4526ea58fb3f  CAMPAIGN03110       2023-11-13
# 9  61c61e9b-9838-4c95-8390-4343fbac7a18  CAMPAIGN46302       2022-09-21
#
#   estimated_arrival  availed
# 0           10 days        1
# 1           13 days        0
# 2            3 days        1
# 3            8 days        1
# 4           14 days        1
# 5           11 days        1
# 6           10 days        1
# 7            7 days        1
# 8            3 days        1
# 9            9 days        1

# %%
df_transaction_campaign_data.tail(10)
# Out:
#                                     order_id    campaign_id transaction_date  \
# 124877  a397c17b-956f-4dce-8b0c-d8d6234f1de8  CAMPAIGN24776       2020-02-04
# 124878  d5dbea32-829e-474c-8d88-cadcb993a944  CAMPAIGN29983       2021-11-23
# 124879  238f761a-f1bf-4f6c-a37a-fff7f6574f8c  CAMPAIGN33679       2022-01-06
# 124880  ceafa665-307f-4c9e-b1bd-79577a450eb9  CAMPAIGN46302       2022-02-14
# 124881  f628455c-ad0a-444f-96c3-931f6a1912e9  CAMPAIGN11190       2022-01-23
# 124882  6a5163c2-ba62-461c-a729-5b06fe266bd9  CAMPAIGN61872       2022-04-14
# 124883  883e2fe2-bbdf-4b5e-8348-c2bcba07da0e  CAMPAIGN11190       2022-11-23
# 124884  575b0a2d-5539-4565-a10b-1f4f6516cd27  CAMPAIGN33679       2023-07-28
# 124885  ba506489-1505-481d-b0b1-8cdbf04a515f  CAMPAIGN49972       2020-04-12
# 124886  2b2e775f-d6cd-4659-9a88-b4950bc326c0  CAMPAIGN52447       2023-03-24
#
#        estimated_arrival  availed
# 124877           14 days        1
# 124878            8 days        1
# 124879           10 days        1
# 124880           12 days        1
# 124881            9 days        0
# 124882           12 days        0
# 124883           15 days        1
# 124884           12 days        1
# 124885            6 days        1
# 124886           15 days        1

# %%
df_transaction_campaign_data.iloc[300:500]
# Out:
#                                  order_id    campaign_id transaction_date  \
# 300  4f1da4b2-1782-4ebe-b6c9-7dd2256e3189  CAMPAIGN29983       2020-09-22
# 301  65872179-0051-48cb-9390-8484ee4a5f56  CAMPAIGN52447       2023-08-30
# 302  175aba9f-ba56-4d55-80ac-55fe5ced4cbd  CAMPAIGN46302       2022-05-27
# 303  957a8b8c-3996-4780-84cf-ebc92485d3cc  CAMPAIGN11190       2021-11-16
# 304  54f13dae-2641-4e71-8201-4a1e4e762d9d  CAMPAIGN46302       2021-03-02
# ..                                    ...            ...              ...
# 495  9eade34d-7cfe-4797-af25-78ce21e9ff23  CAMPAIGN29983       2021-08-25
# 496  d2030212-0411-46a2-af96-f37128864655  CAMPAIGN53595       2021-05-01
# 497  fe1f4d70-34cb-4a7b-8927-d5078acad8bc  CAMPAIGN24776       2022-06-30
# 498  b448a2a2-3a5e-415b-89d2-680adb32714f  CAMPAIGN46302       2022-06-02
# 499  01469eaf-c317-4cfc-923b-bcee4aa07bad  CAMPAIGN11190       2022-10-31
#
#     estimated_arrival  availed
# 300            9 days        1
# 301           15 days        1
# 302            9 days        0
# 303           13 days        0
# 304           11 days        1
# ..                ...      ...
# 495            8 days        0
# 496           11 days        1
# 497           12 days        1
# 498            8 days        1
# 499            4 days        1
#
# [200 rows x 5 columns]

# %%
df_transaction_campaign_data['estimated_arrival'].unique()
# Out:
# array(['10 days', '13 days', '3 days', '8 days', '14 days', '11 days',
#        '7 days', '9 days', '4 days', '5 days', '12 days', '6 days',
#        '15 days'], dtype=object)

# %%
#checking for null values
null_prod_type = df_transaction_campaign_data.isnull().any(axis=1)
null_rows = df_transaction_campaign_data[null_prod_type]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [order_id, campaign_id, transaction_date, estimated_arrival, availed]
# Index: []

# %%
df_transaction_campaign_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124887 entries, 0 to 124886
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   order_id           124887 non-null  object
#  1   campaign_id        124887 non-null  object
#  2   transaction_date   124887 non-null  datetime64[ns]
#  3   estimated_arrival  124887 non-null  object
#  4   availed            124887 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 4.8+ MB

# %%
df_transaction_campaign_data.duplicated().sum()
# Out:
# 0
